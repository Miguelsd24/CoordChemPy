# %% [markdown]
# <div style="text-align: center; background-color: #42424254; padding: 20px; border-radius: 10px;">
#     <h1 style="color: #ffffff; margin-bottom: 0;">CoordChemPy</h1>
#     <p style="font-style: italic; text-align: center;  color: #ffffff;">The essential Python toolkit for inorganic chemistry students and researchers.</p>
# </div>

# %% [markdown]
# Pour lancer : python -m voila notebook/coordchem.ipynb --theme=dark

# %% [markdown]
# ## Introduction

# %%
import sys
import os

# Add the 'src' directory to the path
sys.path.append(os.path.abspath("../src"))

import coordchem as cc
from coordchem import show_analysis
sys.tracebacklimit = 0

# %%
formula = "[Pt(NH3)2(Cl)4]"
ligand = "m-edta"

#print(cc.get_clean_formula(formula, counter_ions))
#print(cc.parse_metal(formula))
#print(cc.parse_ligands(formula))
#print(cc.ligands_list(formula))
#print(cc.complexe_charge(formula))
#print(cc.parse_elements(formula))
#print(cc.ligands_charge(formula))
#print(cc.oxidation_state(formula))
#print(cc.metal_charge(formula))
#print(cc.count_bridging_ligands(formula))
#print(cc.bond_order(formula))
#print(cc.name_or_abbr_ligands(ligand))
#print(cc.naming_compound(formula))
#print(cc.is_an_abbr(ligand))
show_analysis(formula)
# Out:
# * **Formula** : $[Pt(NH_{3})_{2}Cl_{4}]$
# * **IUPAC Name** : Diamminetetrachloroplatinum(IV)
# * **Metal oxidation state** : Pt (4+)
# * **Electronic structure** : [Xe] 6s0 5d6
# * **Electron count** : 18
# * **Isomers:** This compound has 2 stereoisomers and 0 enantiomeres pairs
# * **Stability index** : 50/100
# * **Probable geometry** : Octahedral

# %%
compound = cc.create_compound_render(formula)
cc.render_molecule_notebook(compound)
# Out:
# <div id="3dmolviewer_17782727519301713"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17782727519301713" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17782727519301713 = null;
# var warn = document.getElementById("3dmolwarning_17782727519301713");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17782727519301713 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17782727519301713"),{backgroundColor:"white"});
# viewer_17782727519301713.zoomTo();
# 	viewer_17782727519301713.addModel("13\n\nPt      0.000000000000000      0.000000000000000      0.000000000000000\nN       1.700000000000000      0.000000000000000      0.000000000000000\nH       2.300230997638723      0.000000000000000     -0.849307217368146\nH       2.300230997638723     -0.519815292094012      0.424653608684073\nH       2.300230997638723      0.519815292094011      0.424653608684073\nN      -1.700000000000000      0.000000000000000      0.000000000000000\nH      -2.300230997638723      0.000000000000000      0.849307217368146\nH      -2.300230997638723     -0.519815292094012     -0.424653608684073\nH      -2.300230997638723      0.519815292094011     -0.424653608684073\nCl      0.000000000000000      1.700000000000000      0.000000000000000\nCl      0.000000000000000     -1.700000000000000      0.000000000000000\nCl      0.000000000000000      0.000000000000000      1.700000000000000\nCl      0.000000000000000      0.000000000000000     -1.700000000000000\n","xyz");
# 	viewer_17782727519301713.setStyle({"stick": {}, "sphere": {"scale": 0.4}});
# 	viewer_17782727519301713.zoomTo();
# viewer_17782727519301713.render();
# });
# </script>
