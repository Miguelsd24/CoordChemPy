# %% [markdown]
# ---
# title: "CoordChemPy"
# subtitle: "The essential Python toolkit for inorganic chemistry students and researchers."
# author: "Miguel Sousa, Raphaël Lecci, Amine Sellah"
# format:
#   revealjs:
#     slide-number: true
#     self-contained: true
# ---
#
# ## Slide 1
# Pour lancer avec quatro:
# quarto render notebook/coordchem.ipynb --embed-resources --execute
# Pour lancer avec quatro: quarto render notebook/test.ipynb --to revealjs --embed-resources --execute
# pour lancer avec voila: python -m voila notebook/coordchem.ipynb --theme=dark
# ## Slide 2
#
# World

# %%
import sys
import os

# Add the 'src' directory to the path
sys.path.append(os.path.abspath("../src"))

import coordchem as cc
from coordchem import show_analysis
sys.tracebacklimit = 0

# %%
formula = "[Pt(NH3)2(Cl)4]"
show_analysis(formula)
# Out:
# * **Formula** : $[Pt(NH_{3})_{2}Cl_{4}]$
# * **IUPAC Name** : Diamminetetrachloroplatinum(IV)
# * **Metal oxidation state** : Pt (4+)
# * **Electronic structure** : [Xe] 6s0 5d6
# * **Electron count** : 18
# * **Isomers:** This compound has 2 stereoisomers and 0 enantiomeres pairs
# * **Stability index** : 50/100
# * **Probable geometry** : Octahedral
